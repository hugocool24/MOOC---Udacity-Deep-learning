# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3083, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.660099
# Nearest to there: odegard, mull, stol, aafc, toussaint, mariana, bribed, hoo,
# Nearest to over: interpreting, famously, proclus, roller, alejandro, cranberries, safed, schoolmaster,
# Nearest to be: lomborg, headline, pullback, islander, wf, uplift, bode, paraguayan,
# Nearest to can: is, gojoseon, deeply, moro, motive, iceni, nel, narration,
# Nearest to are: quijote, amylase, participatory, renewing, mishnah, aspartic, anteaters, kyd,
# Nearest to in: sennett, gamut, detachable, reptile, appel, pros, kantele, infielder,
# Nearest to it: linz, champion, lithographs, eukaryotes, dagda, bessie, fruitful, killings,
# Nearest to but: insulate, signifies, striped, shuts, daro, grandmasters, holder, predominates,
# Nearest to during: breathtaking, substitutes, shield, parameters, voted, vg, riders, jogaila,
# Nearest to were: proficiency, sabbatical, albans, marcello, sweat, greet, narcotics, familial,
# Nearest to people: hopkinson, whipping, building, abbey, jamaat, tuareg, scotsman, airy,
# Nearest to or: shaitan, marvelous, iie, nm, retort, came, hunts, supergravity,
# Nearest to other: galeon, melanoleuca, restlessness, conversation, anointing, nay, marjoram, jewish,
# Nearest to used: janis, infinitum, aam, wheatstone, nerd, mishnaic, retaining, fatigue,
# Nearest to states: chuang, chemically, conscious, uae, freikorps, musashi, missed, regress,
# Nearest to of: riffs, ifc, oligocene, nizam, quantification, predicament, medline, admittance,
# Average loss at step 2000: 4.362775
# Average loss at step 4000: 3.862533
# Average loss at step 6000: 3.787235
# Average loss at step 8000: 3.688699
# Average loss at step 10000: 3.614701
# Nearest to there: it, they, he, also, transpersonal, toussaint, cristina, played,
# Nearest to over: interpreting, proclus, quickly, platforms, donegal, alejandro, cranberries, atonality,
# Nearest to be: have, refer, was, by, is, lymphatic, stereo, absalom,
# Nearest to can: may, would, to, must, will, amillennialism, deeply, if,
# Nearest to are: were, is, have, was, spouses, bookmarks, apocryphal, can,
# Nearest to in: of, on, at, with, from, during, among, morum,
# Nearest to it: he, this, not, they, there, which, mostar, she,
# Nearest to but: tuileries, generally, albatross, findable, although, which, insulate, sit,
# Nearest to during: in, riders, graham, vestibule, coeducational, parameters, heuss, shield,
# Nearest to were: are, was, proficiency, recitation, scouring, roz, be, reservoirs,
# Nearest to people: electrochemistry, hopkinson, masters, jamaat, rumi, petersen, kippur, scotsman,
# Nearest to or: and, than, s, capitolina, with, shoah, julie, tong,
# Nearest to other: nay, jewish, distal, anointing, aliases, tightened, materia, recognizing,
# Nearest to used: severe, janis, discount, numeric, acronym, reserves, nigel, mishnaic,
# Nearest to states: uae, others, chuang, bendis, notices, arousing, farmer, abbey,
# Nearest to of: in, for, from, at, alphabetic, against, discharge, infibulation,
# Average loss at step 12000: 3.605745
# Average loss at step 14000: 3.573756
# Average loss at step 16000: 3.413024
# Average loss at step 18000: 3.458029
# Average loss at step 20000: 3.544118
# Nearest to there: they, it, he, which, also, transpersonal, generally, shouts,
# Nearest to over: interpreting, proclus, platforms, alejandro, atonality, nomenclature, cranberries, localized,
# Nearest to be: refer, have, been, was, were, by, is, minurso,
# Nearest to can: may, would, will, could, must, should, might, amillennialism,
# Nearest to are: were, is, have, bookmarks, was, petn, semiconductor, minds,
# Nearest to in: at, on, among, by, during, with, and, phrase,
# Nearest to it: he, this, there, they, which, she, not, possible,
# Nearest to but: however, though, which, although, since, when, and, that,
# Nearest to during: in, at, graham, coeducational, within, parameters, riders, heuss,
# Nearest to were: are, was, had, have, proficiency, be, bookmarks, by,
# Nearest to people: men, electrochemistry, rumi, languages, hopkinson, customary, jamaat, approximated,
# Nearest to or: and, than, with, oshii, circular, geodetic, tong, utub,
# Nearest to other: distal, many, different, padding, jewish, some, nay, asteroids,
# Nearest to used: known, called, discount, numeric, seen, produced, hieroglyphics, reserves,
# Nearest to states: chuang, others, uae, bendis, notices, chemically, farmer, arousing,
# Nearest to of: discharge, in, for, ratites, infects, joanie, mirage, alphabetic,
# Average loss at step 22000: 3.505193
# Average loss at step 24000: 3.490020
# Average loss at step 26000: 3.481993
# Average loss at step 28000: 3.480585
# Average loss at step 30000: 3.500071
# Nearest to there: it, they, he, this, often, clearly, also, usually,
# Nearest to over: when, into, usenet, platforms, atonality, donegal, discontinued, famously,
# Nearest to be: have, refer, been, produce, is, are, were, minurso,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to are: were, is, have, although, be, do, these, bookmarks,
# Nearest to in: of, at, during, among, americana, on, from, since,
# Nearest to it: he, there, this, she, they, also, which, sometimes,
# Nearest to but: however, and, although, though, which, when, or, microphone,
# Nearest to during: in, after, parameters, when, at, within, riders, graham,
# Nearest to were: are, was, had, have, been, proficiency, is, bookmarks,
# Nearest to people: men, artworks, members, electrochemistry, customary, jamaat, individuals, others,
# Nearest to or: and, but, than, with, naughton, exe, brigade, horse,
# Nearest to other: various, different, distal, padding, many, some, nay, such,
# Nearest to used: known, called, written, produced, seen, noted, smog, accepted,
# Nearest to states: kingdom, chuang, others, farmer, bendis, arousing, chemically, communities,
# Nearest to of: in, from, for, and, infects, cruise, sulaiman, against,
# Average loss at step 32000: 3.501197
# Average loss at step 34000: 3.495759
# Average loss at step 36000: 3.456523
# Average loss at step 38000: 3.305271
# Average loss at step 40000: 3.427145
# Nearest to there: they, it, he, which, usually, often, also, transpersonal,
# Nearest to over: platforms, when, into, believable, atonality, atari, quickly, donegal,
# Nearest to be: been, refer, have, were, are, is, falsification, produce,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to are: were, is, have, be, bookmarks, include, rotations, ration,
# Nearest to in: and, of, from, on, during, at, castillian, to,
# Nearest to it: he, there, she, this, they, which, also, what,
# Nearest to but: however, and, though, although, which, before, until, see,
# Nearest to during: at, after, parameters, graham, within, in, before, until,
# Nearest to were: are, have, was, be, sparring, had, been, although,
# Nearest to people: men, languages, individuals, members, stamford, jamaat, customary, electrochemistry,
# Nearest to or: and, than, a, no, circular, tong, utub, the,
# Nearest to other: different, various, distal, padding, nay, shrapnel, telemann, fasci,
# Nearest to used: known, found, seen, available, written, referred, sold, considered,
# Nearest to states: kingdom, others, chuang, nations, communities, farmer, severus, ricky,
# Nearest to of: in, from, automator, for, invoking, ratites, snowfalls, deletions,
# Average loss at step 42000: 3.433804
# Average loss at step 44000: 3.454344
# Average loss at step 46000: 3.448018
# Average loss at step 48000: 3.359263
# Average loss at step 50000: 3.384046
# Nearest to there: they, it, he, we, usually, she, now, still,
# Nearest to over: into, wells, believable, mondegreens, melvins, off, hence, when,
# Nearest to be: was, refer, been, were, being, have, produce, become,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to are: were, is, have, these, be, bookmarks, sparring, ultrasound,
# Nearest to in: during, on, from, americana, of, since, between, until,
# Nearest to it: he, there, she, this, they, then, theodoric, often,
# Nearest to but: however, although, though, and, when, while, that, rectangular,
# Nearest to during: after, in, within, until, at, repeaters, under, graham,
# Nearest to were: are, was, have, be, sparring, had, been, although,
# Nearest to people: men, members, individuals, stamford, jamaat, triumph, others, jews,
# Nearest to or: and, than, manors, suo, vicki, destruct, eradication, dolphins,
# Nearest to other: various, different, distal, many, materialistic, nay, some, padding,
# Nearest to used: known, written, seen, referred, considered, available, found, described,
# Nearest to states: kingdom, nations, chuang, others, farmer, amaterasu, chemically, perception,
# Nearest to of: in, and, lanterns, infects, unintended, groot, ratites, mirage,
# Average loss at step 52000: 3.437070
# Average loss at step 54000: 3.425610
# Average loss at step 56000: 3.440301
# Average loss at step 58000: 3.394752
# Average loss at step 60000: 3.396767
# Nearest to there: it, they, he, she, this, now, still, we,
# Nearest to over: into, through, stuntman, believable, ionized, melvins, around, seaweed,
# Nearest to be: been, refer, become, are, is, were, produce, have,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to are: were, is, have, be, include, these, those, milk,
# Nearest to in: during, within, of, since, among, lusitani, including, at,
# Nearest to it: he, there, she, this, they, which, also, holden,
# Nearest to but: however, although, and, though, than, humiliated, rectangular, phelps,
# Nearest to during: after, in, before, until, within, despite, following, when,
# Nearest to were: are, was, sparring, had, have, including, although, be,
# Nearest to people: men, members, children, individuals, stamford, others, scholars, christians,
# Nearest to or: and, than, manors, circular, logically, impulse, vicki, jaian,
# Nearest to other: different, various, distal, nay, padding, many, pernoud, telemann,
# Nearest to used: known, seen, written, cited, considered, found, called, referred,
# Nearest to states: kingdom, nations, others, brochure, countries, dissident, amaterasu, chuang,
# Nearest to of: in, for, like, infects, lanterns, including, alphabetic, lowest,
# Average loss at step 62000: 3.238535
# Average loss at step 64000: 3.249788
# Average loss at step 66000: 3.404708
# Average loss at step 68000: 3.390854
# Average loss at step 70000: 3.358640
# Nearest to there: it, they, he, we, often, still, usually, now,
# Nearest to over: stuntman, around, ionized, believable, off, philippines, back, melvins,
# Nearest to be: been, refer, become, is, were, being, have, produce,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to are: were, have, is, include, these, including, although, those,
# Nearest to in: within, during, on, among, since, including, at, by,
# Nearest to it: he, there, she, this, they, still, we, also,
# Nearest to but: however, although, which, though, and, than, see, that,
# Nearest to during: after, within, until, in, before, despite, through, repeaters,
# Nearest to were: are, was, have, had, aau, be, sparring, although,
# Nearest to people: men, members, children, individuals, stamford, god, players, inhabitants,
# Nearest to or: and, than, any, vicki, oshii, like, implantation, weaned,
# Nearest to other: various, different, distal, padding, pernoud, many, bock, including,
# Nearest to used: known, seen, cited, referred, described, written, designed, found,
# Nearest to states: kingdom, nations, countries, amaterasu, dissident, chad, ricky, erect,
# Nearest to of: including, workload, and, in, lanterns, infibulation, groot, include,
# Average loss at step 72000: 3.374292
# Average loss at step 74000: 3.347272
# Average loss at step 76000: 3.314838
# Average loss at step 78000: 3.355169
# Average loss at step 80000: 3.376343
# Nearest to there: it, they, he, often, she, we, usually, now,
# Nearest to over: off, around, ionized, schloss, into, before, melvins, cai,
# Nearest to be: been, have, refer, become, being, produce, falsification, choose,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to are: were, is, have, include, those, require, including, these,
# Nearest to in: within, during, on, at, since, millionth, through, from,
# Nearest to it: he, she, there, this, they, still, we, never,
# Nearest to but: however, although, though, see, which, while, and, than,
# Nearest to during: after, before, in, within, despite, when, until, although,
# Nearest to were: are, was, had, have, aau, those, sparring, been,
# Nearest to people: men, children, members, individuals, god, women, customary, stamford,
# Nearest to or: and, than, vicki, while, destruct, anaxagoras, resurrecting, patrol,
# Nearest to other: various, including, padding, pernoud, distal, many, different, bock,
# Nearest to used: known, seen, referred, designed, cited, written, called, available,
# Nearest to states: kingdom, nations, countries, chad, farmer, ricky, state, dissident,
# Nearest to of: yuga, in, latest, flasks, ratites, randomized, infibulation, geocentric,
# Average loss at step 82000: 3.405002
# Average loss at step 84000: 3.412416
# Average loss at step 86000: 3.387812
# Average loss at step 88000: 3.353652
# Average loss at step 90000: 3.369083
# Nearest to there: it, they, he, we, she, now, still, sometimes,
# Nearest to over: off, around, through, cai, robson, ionized, tashfin, within,
# Nearest to be: been, become, refer, was, produce, being, have, falsification,
# Nearest to can: may, could, will, must, should, would, might, cannot,
# Nearest to are: were, is, have, include, these, although, require, while,
# Nearest to in: within, during, under, around, millionth, of, at, repeaters,
# Nearest to it: he, she, there, this, they, itself, actually, we,
# Nearest to but: however, although, and, though, which, while, leaving, until,
# Nearest to during: after, until, in, despite, within, before, under, although,
# Nearest to were: are, had, was, have, while, sparring, aau, been,
# Nearest to people: men, members, children, women, players, individuals, god, citizens,
# Nearest to or: and, than, vicki, choruses, deciphering, manors, scuola, coolest,
# Nearest to other: various, pernoud, distal, padding, including, bock, nay, bookstores,
# Nearest to used: known, referred, seen, designed, cited, defined, called, sold,
# Nearest to states: kingdom, nations, us, farmer, countries, zealand, heater, corporations,
# Nearest to of: for, in, groot, including, alphabetic, include, ratites, allegro,
# Average loss at step 92000: 3.396460
# Average loss at step 94000: 3.257292
# Average loss at step 96000: 3.356689
# Average loss at step 98000: 3.243707
# Average loss at step 100000: 3.352682
# Nearest to there: they, it, he, still, now, we, often, she,
# Nearest to over: around, off, cai, within, tashfin, ionized, through, confession,
# Nearest to be: been, being, are, refer, is, become, have, falsification,
# Nearest to can: may, could, must, will, would, might, should, cannot,
# Nearest to are: were, be, have, is, include, bookmarks, while, sparring,
# Nearest to in: within, during, at, on, from, including, through, among,
# Nearest to it: he, she, this, there, they, actually, still, which,
# Nearest to but: however, although, though, and, while, which, where, when,
# Nearest to during: after, in, within, until, despite, before, under, through,
# Nearest to were: are, have, had, was, these, racketeering, aau, neuropathy,
# Nearest to people: men, children, players, members, individuals, women, jews, students,
# Nearest to or: and, than, suo, while, vicki, like, without, anaxagoras,
# Nearest to other: various, pernoud, others, padding, bookstores, including, distal, different,
# Nearest to used: seen, known, referred, defined, available, designed, found, sold,
# Nearest to states: kingdom, nations, countries, zealand, state, us, corporations, hawke,
# Nearest to of: including, infibulation, groot, in, winona, flasks, ratites, latest,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        #Load labels and data
        batch_labels, batch_data = generate_batch(batch_size, 
        num_skips, skip_window)
        #Reshaping the data and labels
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-18-aa3d8ff810a6>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.287192
# Nearest to there: hunt, largely, habsburg, ionosphere, somalia, kinder, erection, khayyam,
# Nearest to over: interment, faculty, dembski, mis, dedicated, bannerman, bobble, urbino,
# Nearest to be: breeds, bruised, colfax, spearheaded, eldr, dumont, bingham, knute,
# Nearest to can: ayyubid, produces, creationists, negotiator, andrews, iceman, radial, suitability,
# Nearest to are: mantle, aggression, saussure, detachable, enrico, clock, shortly, opolska,
# Nearest to in: hay, erdrich, abstraction, leased, portugu, theorized, announcer, buster,
# Nearest to it: gzip, ishmael, sumerian, sake, strangled, superpowered, pirate, chosroes,
# Nearest to but: hiroshima, brotherly, pollinators, brilliance, treated, gammu, bates, organize,
# Nearest to during: lakoff, abate, joystick, rial, pessimism, gael, evaluation, apulia,
# Nearest to were: democracies, radiosity, dmu, synthesizer, ugaritic, nl, purports, chromium,
# Nearest to people: channelled, sculptor, bridgeport, wounds, isbns, advancing, ecclesiastica, give,
# Nearest to or: aviation, headmaster, jpeg, saar, open, scioto, cav, joke,
# Nearest to other: itosu, maria, honeybee, crept, gregg, retinue, kwahu, foals,
# Nearest to used: flavorings, unconquered, praises, soga, undermine, adar, semiconducting, adom,
# Nearest to states: valdez, hohner, bukhari, tangents, trim, gender, kroeber, derive,
# Nearest to of: sibilants, hakka, sincere, fawlty, melanesian, conducts, suggest, fermanagh,
# Average loss at step 2000: 4.371481
# Average loss at step 4000: 3.872088
# Average loss at step 6000: 3.802394
# Average loss at step 8000: 3.756856
# Average loss at step 10000: 3.615947
# Nearest to there: it, largely, they, constipation, hunt, plateau, motivational, eventually,
# Nearest to over: mis, omphale, dedicated, faculty, complicating, liberator, revision, exmoor,
# Nearest to be: have, colfax, was, is, breeds, cryptanalysis, operand, neighbourhoods,
# Nearest to can: would, may, could, must, radial, will, should, usually,
# Nearest to are: were, is, have, qualification, introspective, was, capcom, callet,
# Nearest to in: on, from, of, by, and, at, with, between,
# Nearest to it: he, this, there, which, she, upheld, champions, not,
# Nearest to but: they, hiroshima, and, sixes, research, discarding, remained, trophies,
# Nearest to during: minimized, pessimism, in, gael, html, rial, marais, evaluation,
# Nearest to were: are, was, have, is, qualification, sexually, saudi, by,
# Nearest to people: entheogen, suitors, blades, specifications, norepinephrine, hilbert, mathbf, levelling,
# Nearest to or: and, p, for, triangular, lepidus, s, slice, superconductor,
# Nearest to other: gregg, itosu, hyphens, morphologically, beeswax, smiling, thick, nongovernmental,
# Nearest to used: menu, seen, unconquered, flavorings, voroshilov, hiking, numerator, found,
# Nearest to states: hohner, recourse, production, bukhari, gender, tangents, kroeber, valdez,
# Nearest to of: and, in, for, with, greta, at, schneider, azt,
# Average loss at step 12000: 3.580690
# Average loss at step 14000: 3.617096
# Average loss at step 16000: 3.583039
# Average loss at step 18000: 3.572735
# Average loss at step 20000: 3.545311
# Nearest to there: they, it, largely, still, hunt, he, usually, constipation,
# Nearest to over: alfons, mis, johore, from, despite, faculty, redskins, icrm,
# Nearest to be: have, by, colfax, been, was, are, were, vai,
# Nearest to can: may, would, could, must, will, should, might, aleksandar,
# Nearest to are: were, is, have, qualification, cno, be, bowers, samuelson,
# Nearest to in: at, from, of, between, on, during, despite, for,
# Nearest to it: he, this, she, there, they, which, also, not,
# Nearest to but: however, and, gst, though, although, subsection, discarding, agile,
# Nearest to during: at, in, after, when, minimized, following, under, by,
# Nearest to were: are, was, have, is, had, be, and, qualification,
# Nearest to people: those, specifications, blades, megabits, footing, punk, strained, mathbf,
# Nearest to or: and, than, distrito, qos, rohan, before, curative, straddles,
# Nearest to other: gregg, itosu, rape, morphologically, horizontal, different, many, hyphens,
# Nearest to used: seen, found, menu, unconquered, known, quack, defined, allegiance,
# Nearest to states: recourse, tangents, production, hohner, kroeber, cont, lpg, valdez,
# Nearest to of: in, and, at, uncanny, for, during, schneider, from,
# Average loss at step 22000: 3.528644
# Average loss at step 24000: 3.441175
# Average loss at step 26000: 3.415311
# Average loss at step 28000: 3.477868
# Average loss at step 30000: 3.407922
# Nearest to there: it, they, he, she, largely, still, which, now,
# Nearest to over: postman, mis, alfons, leeward, aarhus, eriksson, almond, redskins,
# Nearest to be: have, been, is, are, hephaestion, were, was, vai,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to are: were, have, is, be, cno, include, qualification, including,
# Nearest to in: on, at, during, of, from, within, under, after,
# Nearest to it: he, she, there, this, which, not, what, they,
# Nearest to but: however, although, though, and, frequently, that, does, cytology,
# Nearest to during: in, when, after, at, following, under, minimized, rabbis,
# Nearest to were: are, was, had, have, cno, be, been, gallienus,
# Nearest to people: those, blades, parts, writers, blackface, footing, mathbf, specifications,
# Nearest to or: and, chargers, than, bunyan, straddles, distrito, marley, packs,
# Nearest to other: itosu, different, rape, gregg, various, morphologically, most, hyphens,
# Nearest to used: seen, found, known, possible, written, menu, considered, laconia,
# Nearest to states: kingdom, production, clap, hohner, recourse, confirms, valdez, cont,
# Nearest to of: in, pap, and, schneider, biochemistry, poindexter, perestroika, schala,
# Average loss at step 32000: 3.425240
# Average loss at step 34000: 3.437464
# Average loss at step 36000: 3.366373
# Average loss at step 38000: 3.491740
# Average loss at step 40000: 3.443534
# Nearest to there: they, it, he, she, we, still, largely, usually,
# Nearest to over: alfons, sheila, mis, postman, leeward, aarhus, azar, eriksson,
# Nearest to be: been, have, were, is, was, by, hephaestion, vai,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to are: were, have, is, these, those, cno, include, do,
# Nearest to in: on, during, at, within, from, minimized, under, hermas,
# Nearest to it: he, she, there, this, they, which, what, we,
# Nearest to but: however, although, and, though, until, which, that, cytology,
# Nearest to during: after, when, in, under, following, before, valiente, at,
# Nearest to were: are, was, have, had, been, be, when, cno,
# Nearest to people: those, writers, women, blades, accommodations, animals, bukovina, countries,
# Nearest to or: and, challengers, straddles, than, bunyan, chargers, pap, articulated,
# Nearest to other: itosu, many, various, rape, different, hyphens, some, gregg,
# Nearest to used: found, seen, known, designed, written, considered, difficult, influenced,
# Nearest to states: kingdom, production, elegance, hohner, recourse, clap, confirms, nations,
# Nearest to of: pap, in, pontus, uncanny, terrain, for, including, kwanza,
# Average loss at step 42000: 3.427922
# Average loss at step 44000: 3.276444
# Average loss at step 46000: 3.409520
# Average loss at step 48000: 3.432436
# Average loss at step 50000: 3.438836
# Nearest to there: they, it, he, she, usually, we, however, still,
# Nearest to over: alfons, sheila, postman, aarhus, azar, through, bald, durian,
# Nearest to be: been, have, is, become, colfax, hephaestion, refer, was,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to are: were, is, include, have, bowers, although, these, those,
# Nearest to in: during, at, within, of, from, on, under, with,
# Nearest to it: he, she, there, this, they, which, upheld, witte,
# Nearest to but: however, although, though, and, until, where, did, does,
# Nearest to during: after, in, when, under, before, for, until, following,
# Nearest to were: are, was, had, have, those, samuelson, cno, including,
# Nearest to people: those, writers, women, men, animals, blades, songs, parts,
# Nearest to or: and, than, distrito, sagas, disenchantment, nkrumah, configuration, but,
# Nearest to other: various, many, rape, different, cynical, itosu, cultural, emboldened,
# Nearest to used: known, seen, found, designed, considered, referred, difficult, written,
# Nearest to states: kingdom, nations, elegance, us, clap, warmest, production, gog,
# Nearest to of: in, same, original, s, for, following, sparsely, including,
# Average loss at step 52000: 3.454518
# Average loss at step 54000: 3.430991
# Average loss at step 56000: 3.402606
# Average loss at step 58000: 3.282266
# Average loss at step 60000: 3.383075
# Nearest to there: they, it, he, she, still, now, usually, we,
# Nearest to over: alfons, aarhus, from, postman, burning, across, cplp, hamza,
# Nearest to be: been, become, have, was, is, produce, belonging, hephaestion,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to are: were, include, those, is, have, cno, including, samuelson,
# Nearest to in: on, during, since, under, at, within, throughout, from,
# Nearest to it: he, she, there, this, they, which, today, we,
# Nearest to but: however, although, though, and, until, which, where, puppet,
# Nearest to during: after, in, before, when, under, throughout, since, following,
# Nearest to were: are, was, those, including, have, samuelson, being, been,
# Nearest to people: those, writers, women, songs, men, parts, blades, animals,
# Nearest to or: and, whose, own, than, challengers, but, cloister, lest,
# Nearest to other: various, including, different, several, itosu, gregg, emboldened, some,
# Nearest to used: known, seen, found, referred, considered, difficult, designed, available,
# Nearest to states: nations, kingdom, countries, state, countdown, elegance, gog, serpents,
# Nearest to of: including, original, imax, in, for, uncanny, beg, tegucigalpa,
# Average loss at step 62000: 3.445060
# Average loss at step 64000: 3.362247
# Average loss at step 66000: 3.344983
# Average loss at step 68000: 3.387001
# Average loss at step 70000: 3.372233
# Nearest to there: they, it, he, still, she, we, usually, however,
# Nearest to over: alfons, across, postman, into, burning, sheila, fia, cplp,
# Nearest to be: been, have, become, was, belonging, were, spc, being,
# Nearest to can: could, will, would, may, must, should, cannot, might,
# Nearest to are: were, is, include, have, including, cno, those, samuelson,
# Nearest to in: during, on, at, within, under, from, until, around,
# Nearest to it: he, she, there, this, they, today, boyz, saba,
# Nearest to but: however, although, though, and, while, until, that, puppet,
# Nearest to during: after, in, before, since, following, until, when, under,
# Nearest to were: are, was, have, those, including, had, samuelson, include,
# Nearest to people: women, men, writers, those, children, blades, mansi, substituting,
# Nearest to or: and, than, beersheba, lest, while, litters, chargers, distrito,
# Nearest to other: various, different, itosu, cultural, remaining, several, emboldened, some,
# Nearest to used: seen, known, found, considered, referred, described, available, written,
# Nearest to states: kingdom, nations, countries, state, clap, baresi, jardines, countdown,
# Nearest to of: including, imax, original, exact, hawke, for, vara, seller,
# Average loss at step 72000: 3.404202
# Average loss at step 74000: 3.388224
# Average loss at step 76000: 3.350583
# Average loss at step 78000: 3.238211
# Average loss at step 80000: 3.372098
# Nearest to there: they, it, he, she, usually, we, still, now,
# Nearest to over: postman, about, sheila, alfons, across, burning, cpm, off,
# Nearest to be: is, been, become, being, hephaestion, are, have, was,
# Nearest to can: will, could, may, would, must, should, might, cannot,
# Nearest to are: were, have, is, include, including, be, those, quintana,
# Nearest to in: during, within, benign, of, since, on, sparsely, with,
# Nearest to it: he, she, there, this, they, we, what, which,
# Nearest to but: however, although, though, while, and, when, until, which,
# Nearest to during: after, before, in, until, since, when, following, throughout,
# Nearest to were: are, was, including, those, had, these, samuelson, have,
# Nearest to people: women, children, writers, men, those, blades, citizens, critics,
# Nearest to or: and, than, while, litters, beersheba, detonates, anticonvulsants, chargers,
# Nearest to other: various, different, remaining, individual, emboldened, cultural, gregg, biological,
# Nearest to used: found, known, seen, referred, available, written, designed, called,
# Nearest to states: nations, kingdom, countries, countdown, gog, state, equate, coffins,
# Nearest to of: in, imax, aldrin, including, and, for, from, exact,
# Average loss at step 82000: 3.297859
# Average loss at step 84000: 3.342143
# Average loss at step 86000: 3.347653
# Average loss at step 88000: 3.323225
# Average loss at step 90000: 3.241287
# Nearest to there: they, it, he, she, we, usually, now, still,
# Nearest to over: alfons, advantage, about, postman, around, dominos, durian, through,
# Nearest to be: become, been, have, hephaestion, refer, was, seem, produce,
# Nearest to can: could, will, would, must, may, should, might, cannot,
# Nearest to are: were, include, have, is, including, samuelson, cno, those,
# Nearest to in: during, at, within, until, on, around, throughout, with,
# Nearest to it: she, he, this, there, they, which, often, reforming,
# Nearest to but: however, although, though, while, and, he, who, until,
# Nearest to during: after, in, before, at, until, following, when, throughout,
# Nearest to were: are, was, had, these, have, being, those, samuelson,
# Nearest to people: women, children, men, man, greenberg, writers, blades, dinara,
# Nearest to or: and, beersheba, stanislavski, mattel, anticonvulsants, challengers, kaleidoscope, und,
# Nearest to other: various, remaining, itosu, different, individual, including, emboldened, gregg,
# Nearest to used: seen, found, known, designed, written, available, spoken, described,
# Nearest to states: nations, kingdom, state, countries, countdown, krak, us, evangelicalism,
# Nearest to of: and, in, showtime, s, tegucigalpa, slick, including, imax,
# Average loss at step 92000: 2.735729
# Average loss at step 94000: 3.100643
# Average loss at step 96000: 3.060868
# Average loss at step 98000: 3.223234
# Average loss at step 100000: 3.281958
# Nearest to there: it, they, he, she, now, still, usually, generally,
# Nearest to over: through, off, advantage, alfons, about, across, around, durian,
# Nearest to be: been, was, become, have, hephaestion, is, being, refer,
# Nearest to can: could, will, would, must, should, may, might, cannot,
# Nearest to are: were, include, those, is, have, samuelson, while, these,
# Nearest to in: within, at, during, since, between, on, from, sparsely,
# Nearest to it: she, he, there, this, what, boyz, they, upheld,
# Nearest to but: however, although, though, while, and, until, when, if,
# Nearest to during: after, at, before, when, following, in, since, near,
# Nearest to were: are, was, those, while, had, have, these, samuelson,
# Nearest to people: women, children, men, citizens, writers, those, blades, man,
# Nearest to or: and, but, than, straddles, fantagraphics, kerenyi, litters, without,
# Nearest to other: various, different, individual, several, itosu, remaining, others, some,
# Nearest to used: seen, known, designed, found, referred, written, recorded, spoken,
# Nearest to states: nations, kingdom, state, us, countries, lysosome, reformulation, ouagadougou,
# Nearest to of: and, despite, imax, for, exact, in, including, tegucigalpa,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
